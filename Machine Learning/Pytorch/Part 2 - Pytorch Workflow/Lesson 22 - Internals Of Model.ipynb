# %% [markdown]
# ### Checking The Contents Of The Pytorch Model
#
# Now with a created model we can check to see whats inside the model, we can do with using .parameters?
#
# ![image.png](attachment:image.png)

# %%
import torch
from torch import nn

# %%
# creating a random seed
torch.manual_seed(246)

# creating an instance of the model which is a subclass of nn.Module
model0 = LinearRegressionModel() # type: ignore

model0
# Out:
# LinearRegressionModel()

# %%
# checking out the parameters

list(model0.parameters())
# at first all of the parameters are completly random, later on after viewing the data does the parameter change
# Out:
# [Parameter containing:
#  tensor([-0.7062], requires_grad=True),
#  Parameter containing:
#  tensor([1.4592], requires_grad=True)]

# %%
model0.state_dict()
# models goal:
# look at the blue dots in the graphs(lesson 19) and adjust the weight and bias to be as close as possible to the known weights and bias stated in lesson 19
# Out:
# OrderedDict([('weights', tensor([-0.7062])), ('bias', tensor([1.4592]))])
