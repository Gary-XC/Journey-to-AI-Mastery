# %% [markdown]
# ### Random Tensors
#
# Creating Random Tensors For Practice

# %% [markdown]
# Notes for remembering the different tensors
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Random tensors are important as many neral networks learn from random numbers which are then adjusted to better represent the data
#
# `Start with random numbers -> look at data -> update the random numbers based on the data that you have --> look at data --> update random numbers`
#
# Torch Random Tensors: https://pytorch.org/docs/stable/generated/torch.rand.html

# %%
import torch
# Creating a Random tensor of size(3,4)

random_tensor = torch.rand(3,4)
random_tensor

# four elements and are have depth of 3
# Out:
# tensor([[0.4542, 0.9024, 0.3220, 0.9164],
#         [0.7125, 0.7219, 0.0133, 0.2252],
#         [0.7128, 0.1062, 0.0346, 0.2370]])

# %%
random_tensor.ndim
# Out:
# 2

# %%
random_tensor2 = torch.rand(1, 10, 10)
random_tensor2,
# 10 total columns and 10 rows. With 10 elemnents in each row
# Out:
# (tensor([[[0.5256, 0.9445, 0.4427, 0.0610, 0.2097, 0.6827, 0.5967, 0.7455,
#            0.2762, 0.3347],
#           [0.7878, 0.1352, 0.8036, 0.9079, 0.9042, 0.6621, 0.8766, 0.3450,
#            0.0644, 0.8385],
#           [0.1793, 0.6300, 0.8233, 0.2577, 0.1020, 0.4454, 0.8845, 0.1573,
#            0.2247, 0.7806],
#           [0.0613, 0.5845, 0.4216, 0.8152, 0.7686, 0.2027, 0.9180, 0.7855,
#            0.3326, 0.9621],
#           [0.5743, 0.0312, 0.4926, 0.5992, 0.9368, 0.8503, 0.0012, 0.8258,
#            0.4325, 0.7190],
#           [0.9664, 0.7563, 0.9041, 0.9612, 0.5372, 0.2062, 0.3927, 0.7627,
#            0.3945, 0.8049],
#           [0.6531, 0.3868, 0.5970, 0.8659, 0.4388, 0.0582, 0.6666, 0.4606,
#            0.3848, 0.5383],
#           [0.5881, 0.7011, 0.3716, 0.0376, 0.7390, 0.7901, 0.9141, 0.7026,
#            0.4795, 0.7940],
#           [0.9751, 0.1921, 0.7263, 0.0347, 0.9066, 0.5592, 0.0842, 0.0518,
#            0.8563, 0.7847],
# ...

# %%
random_tensor2.ndim
# is 3 dimenstions as you gave the function 3 inputs, each of which is a seperate dimension
# Out:
# 3

# %%
# Creating a random tensor that has a simlar shape to a image tensor

randomImageSizeTensor = torch.rand(224, 224, 3) # height, width, colour channels
randomImageSizeTensor.shape, randomImageSizeTensor.ndim
# Out:
# (torch.Size([224, 224, 3]), 3)

# %% [markdown]
# ##### Main Point
# Key Takeaway --> almost any data can be represented as a tensor and a common way for images is to use height, width, and colour channels

# %%
# Challenge Creating your own random tensor how ever you like

randomTensor3 = torch.rand(23, 45, 67, 1, 89, 100)
randomTensor3
# Out:
# tensor([[[[[[6.6168e-01, 3.9903e-01, 6.4113e-01,  ..., 3.9619e-01,
#              2.2902e-01, 6.8880e-02],
#             [2.9171e-01, 4.9063e-01, 5.3406e-01,  ..., 9.6364e-01,
#              3.0202e-01, 3.9946e-01],
#             [7.0291e-01, 4.2714e-01, 7.3797e-02,  ..., 2.2719e-01,
#              2.2632e-01, 5.9418e-01],
#             ...,
#             [1.7916e-01, 3.1626e-01, 6.5895e-01,  ..., 5.6302e-01,
#              2.3469e-01, 7.7466e-01],
#             [1.7952e-01, 3.9358e-01, 9.6637e-01,  ..., 7.3374e-01,
#              4.7854e-01, 3.0209e-01],
#             [5.3167e-01, 7.0568e-01, 2.6477e-02,  ..., 3.6280e-02,
#              6.4219e-01, 9.5357e-01]]],
#
#
#           [[[7.5139e-01, 7.7693e-01, 3.9508e-01,  ..., 8.4604e-01,
#              5.1076e-01, 7.5115e-01],
#             [1.2466e-02, 5.5738e-01, 8.7022e-01,  ..., 8.2898e-01,
#              9.5122e-01, 6.0464e-01],
#             [5.1327e-01, 6.4953e-01, 8.5128e-01,  ..., 6.1484e-01,
# ...
